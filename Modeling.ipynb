# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
train_data2 = pd.read_csv('E:/uni\AI quera\project\data_project1/final_train.csv')
valid_data2 = pd.read_csv('E:/uni\AI quera\project\data_project1/final_valid.csv')
test_data2 = pd.read_csv('E:/uni\AI quera\project\data_project1/final_test.csv')

# %%
y_train = train_data2['full_price']
X_train = train_data2.drop('full_price', axis = 1)

y_valid = valid_data2['full_price']
X_valid = valid_data2.drop('full_price', axis = 1)

y_test = test_data2['full_price']
X_test = test_data2.drop('full_price', axis = 1)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Method 1

# %%
model = LinearRegression(positive=True)
fs = RFE(model, n_features_to_select=30) 
X_train1 = fs.fit_transform(X_train, y_train)
X_valid1 = fs.transform(X_valid)
X_test1 = fs.transform(X_test)
poly_transformer = PolynomialFeatures(degree=2)
X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)
r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -25182.01
# mse =	 25233.27
# mae =	 5.29

# %% [markdown]
# ## Method 2

# %%
#PCA
pca = PCA(n_components=10)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=2)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -233620468598.42
# mse =	 234086674067.37
# mae =	 8923.89

# %% [markdown]
# ## Method 3

# %%
#PCA
pca = PCA(n_components=20)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=2)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -9.420260579688959e+32
# mse =	 9.439059347699533e+32
# mae =	 1051450038317810.9

# %% [markdown]
# ## Method 4

# %%
#PCA
pca = PCA(n_components=5)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=2)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -197311692682.71
# mse =	 197705441530.17
# mae =	 8025.44

# %% [markdown]
# ## Method 5

# %%
#PCA
pca = PCA(n_components=5)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=4)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -4.102254441637429e+20
# mse =	 4.110440768216862e+20
# mae =	 199735896.87

# %% [markdown]
# ## Method 6

# %%
#PCA
pca = PCA(n_components=5)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=1)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -3897.8
# mse =	 3906.58
# mae =	 8.37

# %% [markdown]
# ## Method 7

# %%
#PCA
pca = PCA(n_components=2)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=1)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -2331.31
# mse =	 2336.96
# mae =	 2.55

# %% [markdown]
# ## Method 8

# %%
#PCA
pca = PCA(n_components=2)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=3)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = LinearRegression(positive=True)
model.fit(X_train2, y_train)
# Out:
# LinearRegression(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -133486.43
# mse =	 133753.81
# mae =	 5.75

# %% [markdown]
# ## Method 9

# %%
#PCA
pca = PCA(n_components=2)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=1)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = Ridge(positive=True)
model.fit(X_train2, y_train)
# Out:
# Ridge(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -0.0
# mse =	 1.0
# mae =	 0.8

# %% [markdown]
# ## Method 10

# %%
#PCA
pca = PCA(n_components=2)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=1)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = Ridge(alpha=0.1, positive=True)
model.fit(X_train2, y_train)
# Out:
# Ridge(alpha=0.1, positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -0.0
# mse =	 1.0
# mae =	 0.8

# %% [markdown]
# ## Method 11

# %%
#PCA
pca = PCA(n_components=2)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=1)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = Ridge(alpha=10, positive=True)
model.fit(X_train2, y_train)
# Out:
# Ridge(alpha=10, positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -0.0
# mse =	 1.0
# mae =	 0.8

# %% [markdown]
# ## Method 12

# %%
#PCA
pca = PCA(n_components=5)
X_train1 = pca.fit_transform(X_train)
X_valid1 = pca.fit_transform(X_valid)
X_test1 = pca.fit_transform(X_test)

poly_transformer = PolynomialFeatures(degree=4)

X_train2 = poly_transformer.fit_transform(X_train1)
X_valid2 = poly_transformer.transform(X_valid1)
X_test2 = poly_transformer.transform(X_test1)

model = Ridge(positive=True)
model.fit(X_train2, y_train)
# Out:
# Ridge(positive=True)

# %%
y_pred = model.predict(X_valid2)

r2 = r2_score(y_valid, y_pred)
mse = mean_squared_error(y_valid, y_pred)
mae = mean_absolute_error(y_valid, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -0.0
# mse =	 1.0
# mae =	 0.8

# %%
y_pred = model.predict(X_train2)

r2 = r2_score(y_train, y_pred)
mse = mean_squared_error(y_train, y_pred)
mae = mean_absolute_error(y_train, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 0.0
# mse =	 1.0
# mae =	 0.8

# %%
y_pred = model.predict(X_test2)

r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print("r2 =\t", round(r2, 2))
print("mse =\t", round(mse, 2))
print("mae =\t", round(mae, 2))
# Out:
# r2 =	 -0.0
# mse =	 0.98
# mae =	 0.8
